# %%
pip install openpyxl
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Load the dataset
imported_data = pd.read_excel('Copper_Set.xlsx')

# %%
df=imported_data.copy()

# %%
df
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0    102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0    208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0      4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0    406.686538
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
df['material_ref'].isna().sum()
# Out:
# 77919

# %%
df.isna().sum()
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %%
df['material_ref'] = df['material_ref'].apply(lambda x: None if str(x).startswith('00000') else x)

# %%
df['material_ref'].mode()[0]
# Out:
# 'DX51D+Z'

# %%
df['material_ref']= df['material_ref'].fillna('unknown')

# %%
df.isna().sum()
# Out:
# id                2
# item_date         1
# quantity tons     0
# customer          1
# country          28
# status            2
# item type         0
# application      24
# thickness         1
# width             0
# material_ref      0
# product_ref       0
# delivery date     1
# selling_price     1
# dtype: int64

# %%
df['country'].median()
# Out:
# 30.0

# %%
df['country'].fillna(df['country'].median(), inplace=True)
# Out:
# C:\Users\thiru\AppData\Local\Temp\ipykernel_11120\525712380.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna(df['country'].median(), inplace=True)

# %%
df['application'].median()
# Out:
# 15.0

# %%
df['application'].fillna(df['application'].median(), inplace=True)
# Out:
# C:\Users\thiru\AppData\Local\Temp\ipykernel_11120\2880444620.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['application'].fillna(df['application'].median(), inplace=True)

# %%
df['customer'].mode()[0]
# Out:
# 30157111.0

# %%
df['customer']=df['customer'].fillna(df['customer'].mode()[0])

# %%
df.isna().sum()
# Out:
# id               2
# item_date        1
# quantity tons    0
# customer         0
# country          0
# status           2
# item type        0
# application      0
# thickness        1
# width            0
# material_ref     0
# product_ref      0
# delivery date    1
# selling_price    1
# dtype: int64

# %%
df['thickness']=df['thickness'].fillna(df['thickness'].median())

# %%
df['selling_price'] = df['selling_price'].fillna(df['selling_price'].median())

# %%
df['delivery date'] = df['delivery date'].fillna(df['delivery date'].median())
df['item_date'] = df['item_date'].fillna(df['item_date'].median())
df['status'] = df['status'].fillna(df['status'].mode()[0])

# %%
df[df['id'].isna()]
# Out:
#          id   item_date quantity tons    customer  country          status  \
# 26      NaN  20210401.0      15.92799  30271717.0     28.0  To be approved
# 104566  NaN  20201113.0     27.096376  30197989.0     27.0             Won
#
#        item type  application  thickness   width        material_ref  \
# 26             W         10.0        0.8  1000.0             unknown
# 104566         W         59.0        2.8   959.0  HRCL_DD 12 2.8X959
#
#         product_ref  delivery date  selling_price
# 26           611993     20210701.0         1208.0
# 104566       640665     20201201.0          551.0

# %%
mode_id = df['id'].mode()[0]
df.loc[df['id'].isna(),'id'] = df.loc[df['id'].isna()].index.astype(str) + '_' + mode_id

# %%
df.isna().sum()
# Out:
# id               0
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
df['item_date'] = pd.to_datetime(df['item_date'], format='%Y%m%d', errors='coerce')

# %%
df['delivery date'] = pd.to_datetime(df['delivery date'],format='%Y%m%d',errors='coerce')

# %%
df['delivery date'] = df['delivery date'].fillna(df['item_date'])

# %%
df['item_date'] = df['item_date'].fillna(df['delivery date'])

# %%
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce')

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181672 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181672 non-null  object
#  1   item_date      181672 non-null  datetime64[ns]
#  2   quantity tons  181672 non-null  float64
#  3   customer       181672 non-null  float64
#  4   country        181672 non-null  float64
#  5   status         181672 non-null  object
#  6   item type      181672 non-null  object
#  7   application    181672 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181672 non-null  float64
#  10  material_ref   181672 non-null  object
#  11  product_ref    181672 non-null  int64
#  12  delivery date  181672 non-null  datetime64[ns]
#  13  selling_price  181672 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(4)
# memory usage: 20.8+ MB

# %%
from sklearn.preprocessing import LabelEncoder
import pickle
# Encoding

categorical_cols = ['status', 'item type', 'material_ref']
label_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(label_encoders, f)

# %%
label_encoders
# Out:
# {'status': LabelEncoder(),
#  'item type': LabelEncoder(),
#  'material_ref': LabelEncoder()}

# %%
label_encoders['status']
# Out:
# LabelEncoder()

# %%
df
# Out:
#                                           id  item_date  quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# ...                                      ...        ...            ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02       4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02   -2000.000000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02     406.686538
#
#           customer  country  status  item type  application  thickness  \
# ...

# %%
df['quantity tons'].describe()
# Out:
# count    1.816720e+05
# mean     5.874926e+03
# std      2.349081e+06
# min     -2.000000e+03
# 25%      1.097030e+01
# 50%      3.036464e+01
# 75%      6.716061e+01
# max      1.000000e+09
# Name: quantity tons, dtype: float64

# %%
df[df['quantity tons']<=0]
# Out:
#                                           id  item_date  quantity tons  \
# 105730  36820BDA-8CDF-49F3-89A2-C50A55B70CEB 2020-11-11      -4.000000
# 131473  D03D83BD-3D05-40FB-A71E-6C33CCD06D97 2020-10-02      -1.476794
# 181661  802C8D24-710A-4A96-B3B1-F33F383EC455 2020-07-02     -18.000000
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02   -2000.000000
#
#           customer  country  status  item type  application  thickness  \
# 105730  30203192.0     27.0       7          3         15.0       1.50
# 131473  30199273.0     27.0       0          3         10.0       0.60
# 181661  30200854.0     25.0       7          5         41.0       0.84
# 181671  30200854.0     25.0       7          5         41.0       0.85
#
#          width  material_ref  product_ref delivery date  selling_price
# 105730  1500.0         11485   1332077137    2021-01-01          723.0
# 131473  1220.0         11485       611993    2021-01-01           22.0
# ...

# %%
quantity_data = df[df['quantity tons']>0]

# %%
quantity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181668 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181668 non-null  object
#  1   item_date      181668 non-null  datetime64[ns]
#  2   quantity tons  181668 non-null  float64
#  3   customer       181668 non-null  float64
#  4   country        181668 non-null  float64
#  5   status         181668 non-null  int32
#  6   item type      181668 non-null  int32
#  7   application    181668 non-null  float64
#  8   thickness      181668 non-null  float64
#  9   width          181668 non-null  float64
#  10  material_ref   181668 non-null  int32
#  11  product_ref    181668 non-null  int64
#  12  delivery date  181668 non-null  datetime64[ns]
#  13  selling_price  181668 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int32(3), int64(1), object(1)
# memory usage: 18.7+ MB

# %%
quantity_data.select_dtypes(include=['object','category']).columns
# Out:
# Index(['id'], dtype='object')

# %%
quantity_data
# Out:
#                                           id  item_date  quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# ...                                      ...        ...            ...
# 181667  0B812591-B501-4F34-859A-B06381FAEB44 2020-07-02     106.783299
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02       4.235594
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02     406.686538
#
#           customer  country  status  item type  application  thickness  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
numerical_columns = quantity_data.select_dtypes(include=['float64', 'int64','datetime64[ns]','int32'])
correlation_matrix = numerical_columns.corr()
plt.figure(figsize=(16,8))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', linewidth=0.5)
plt.show()

# %%
df1 = numerical_columns.drop(['delivery date'],axis =1)
plt.figure(figsize=(16,8))
sns.heatmap(df1.corr(), cmap='Blues', annot=True,fmt='.2f', linewidth=.5)
# Out:
# <Axes: >

# %%
from sklearn import linear_model
data1=df.copy()
regr = linear_model.LinearRegression()
x=data1[['thickness','width']]
y= data1['selling_price']
regr.fit(x,y)
predicted = regr.predict([[2,4500]])
print(*predicted)
# Out:
# 5150.9683733882885
# c:\Users\thiru\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Visualize outliers before treatment
plt.figure(figsize=(10, 6))
sns.boxplot(df1[['quantity tons', 'thickness', 'width', 'selling_price']])
plt.title('Boxplot of Continuous Features Before Outlier Treatment')
plt.show()

# %%
sns.violinplot(df1[['quantity tons', 'thickness', 'width', 'selling_price']])
# Out:
# <Axes: >

# %%
from sklearn.ensemble import IsolationForest

# Treat outliers using Isolation Forest
iso = IsolationForest(contamination=0.1, random_state=42)
outliers = iso.fit_predict(df1.select_dtypes(include=['float64', 'int64']))
df2 = df1[outliers != -1]

# %%
outliers
# Out:
# array([ 1, -1,  1, ...,  1,  1,  1])

# %%
df2
# Out:
#         item_date  quantity tons    customer  country  status  item type  \
# 0      2021-04-01      54.151139  30156308.0     28.0       7          5
# 2      2021-04-01     386.127949  30153963.0     30.0       7          6
# 5      2021-04-01     225.790676  30202938.0     25.0       7          5
# 6      2021-04-01       3.522613  30209509.0     30.0       0          5
# 7      2021-04-01     113.387124  30342192.0     32.0       7          5
# ...           ...            ...         ...      ...     ...        ...
# 181667 2020-07-02     106.783299  30200854.0     25.0       7          5
# 181668 2020-07-02     102.482422  30200854.0     25.0       7          5
# 181669 2020-07-02     208.086469  30200854.0     25.0       7          5
# 181670 2020-07-02       4.235594  30200854.0     25.0       7          5
# 181672 2020-07-02     406.686538  30200854.0     25.0       7          5
#
#         application  thickness   width  material_ref  product_ref  \
# ...

# %%
# Visualize outliers after treatment
plt.figure(figsize=(10, 6))
sns.boxplot(df2[['quantity tons', 'thickness', 'width', 'selling_price']])
plt.title('Boxplot of Continuous Features After Outlier Treatment')
plt.show()

# %%
df2[df2['selling_price']>1e8]
# Out:
#        item_date  quantity tons    customer  country  status  item type  \
# 36192 2021-02-19       8.676803  30217607.0     27.0       2          2
#
#        application  thickness   width  material_ref  product_ref  \
# 36192         10.0        0.6  1446.0         11485    164141591
#
#        selling_price
# 36192    100001015.0

# %%
df2_filtered= df2[df2['selling_price']>6000]
df2_filtered
# Out:
#         item_date  quantity tons    customer  country  status  item type  \
# 36192  2021-02-19       8.676803  30217607.0     27.0       2          2
# 76871  2020-12-15      17.995508  30157111.0     78.0       7          5
# 113918 2020-10-28       4.774096  30157111.0     78.0       7          5
# 116445 2020-10-26      20.114277  30157111.0     78.0       2          5
# 123570 2020-10-14       1.792484  30229766.0     84.0       7          5
# 124547 2020-10-13       9.509518  30205658.0     32.0       7          5
# 141122 2020-09-18       7.712359  30157111.0     78.0       7          5
# 153215 2020-08-28      84.282044  30157111.0     78.0       7          5
# 159869 2020-08-10      48.972675  30157111.0     78.0       2          5
#
#         application  thickness   width  material_ref  product_ref  \
# 36192          10.0       0.60  1446.0         11485    164141591
# 76871          41.0       1.15  1500.0          9152       611993
# ...

# %%
df2_filtered.shape
# Out:
# (9, 12)

# %%
df2_filtered= df2[(df2['selling_price']<6000)]

# %%
df2_filtered.shape
# Out:
# (163492, 12)

# %%
plt.figure(figsize=(13,6))
sns.boxplot(df2_filtered[['quantity tons','thickness','width','selling_price']])
plt.title('Boxplot of continuous feature after Outlier Treatment(filtered)')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(df2_filtered['thickness'])
plt.show()

# %%
# Identify skewed continuous features
skewed_features_before = df2_filtered.select_dtypes(include=['float64']).apply(lambda x: x.skew()).sort_values(ascending=False)
#skewed_features_before = skewed_features_before.drop(index='customer')

# Visualize skewness before treatment

# %%
skewed_features_before
# Out:
# customer         233.398978
# quantity tons      5.560726
# thickness          2.042494
# country            0.820483
# application        0.620811
# width              0.584835
# selling_price      0.027125
# dtype: float64

# %%
for feature in skewed_features_before.drop(index='customer').index:
    plt.figure(figsize=(10, 6))
    sns.histplot(df2_filtered['quantity tons'], kde=True)
    plt.title(f'Distribution of {feature} Before Log Transformation')
    plt.show()

# %%
df2_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163492 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      163492 non-null  datetime64[ns]
#  1   quantity tons  163492 non-null  float64
#  2   customer       163492 non-null  float64
#  3   country        163492 non-null  float64
#  4   status         163492 non-null  int32
#  5   item type      163492 non-null  int32
#  6   application    163492 non-null  float64
#  7   thickness      163492 non-null  float64
#  8   width          163492 non-null  float64
#  9   material_ref   163492 non-null  int32
#  10  product_ref    163492 non-null  int64
#  11  selling_price  163492 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(3), int64(1)
# memory usage: 14.3 MB

# %%
import numpy as np

df2_skew = df2_filtered.copy()
# Apply log transformation to skewed features
for feature in skewed_features_before.index:
    df2_skew[feature] = np.log1p(df2_filtered[feature])

# Identify skewed continuous features again after transformation
skewed_features_after = df2_skew.select_dtypes(include=['float64']).apply(lambda x: x.skew()).sort_values(ascending=False)
skewed_features_after = skewed_features_after.drop(index='customer')
# Out:
# c:\Users\thiru\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df2_skew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163492 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      163492 non-null  datetime64[ns]
#  1   quantity tons  163492 non-null  float64
#  2   customer       163492 non-null  float64
#  3   country        163492 non-null  float64
#  4   status         163492 non-null  int32
#  5   item type      163492 non-null  int32
#  6   application    163492 non-null  float64
#  7   thickness      163492 non-null  float64
#  8   width          163492 non-null  float64
#  9   material_ref   163492 non-null  int32
#  10  product_ref    163492 non-null  int64
#  11  selling_price  163490 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(3), int64(1)
# memory usage: 14.3 MB

# %%
skewed_features_after
# Out:
# thickness        0.748980
# country          0.748119
# application      0.241847
# quantity tons    0.019064
# width           -1.284770
# selling_price   -6.149634
# dtype: float64

# %%
#Visualize skewness after treatment
for feature in skewed_features_after.index:
    if skewed_features_after[feature] > 0.5 or skewed_features_after[feature] < -0.5:
        plt.figure(figsize=(10, 6))
        sns.histplot(df2_filtered[feature], kde=True)
        plt.title(f'Distribution of {feature} After Log Transformation')
        plt.show()

# %%
# Investigate the customer column
print(df2_filtered['customer'].describe())
# Out:
# count    1.634920e+05
# mean     3.026601e+07
# std      9.070056e+06
# min      1.245800e+04
# 25%      3.016599e+07
# 50%      3.020312e+07
# 75%      3.027112e+07
# max      2.147484e+09
# Name: customer, dtype: float64

# %%
sns.boxplot(df2_filtered['customer'])
plt.title('Boxplot of Customer Before and After Transformation')
plt.show()

# %%
df2_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163492 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      163492 non-null  datetime64[ns]
#  1   quantity tons  163492 non-null  float64
#  2   customer       163492 non-null  float64
#  3   country        163492 non-null  float64
#  4   status         163492 non-null  int32
#  5   item type      163492 non-null  int32
#  6   application    163492 non-null  float64
#  7   thickness      163492 non-null  float64
#  8   width          163492 non-null  float64
#  9   material_ref   163492 non-null  int32
#  10  product_ref    163492 non-null  int64
#  11  selling_price  163492 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(3), int64(1)
# memory usage: 14.3 MB

# %%
# Example: Drop highly correlated features if any
plt.figure(figsize=(13,5))
correlation_matrix = df2_skew.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5 , )
plt.show()

# Drop columns with high correlation (if needed)
# df.drop(['column_name'], axis=1, inplace=True)

# %%
df3 = df2_skew.drop(columns=['item_date'])

# %%
df3=df3.dropna()

# %%
df2_filtered
# Out:
#         item_date  quantity tons    customer  country  status  item type  \
# 0      2021-04-01      54.151139  30156308.0     28.0       7          5
# 2      2021-04-01     386.127949  30153963.0     30.0       7          6
# 5      2021-04-01     225.790676  30202938.0     25.0       7          5
# 6      2021-04-01       3.522613  30209509.0     30.0       0          5
# 7      2021-04-01     113.387124  30342192.0     32.0       7          5
# ...           ...            ...         ...      ...     ...        ...
# 181667 2020-07-02     106.783299  30200854.0     25.0       7          5
# 181668 2020-07-02     102.482422  30200854.0     25.0       7          5
# 181669 2020-07-02     208.086469  30200854.0     25.0       7          5
# 181670 2020-07-02       4.235594  30200854.0     25.0       7          5
# 181672 2020-07-02     406.686538  30200854.0     25.0       7          5
#
#         application  thickness   width  material_ref  product_ref  \
# ...

# %%
df2_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163492 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      163492 non-null  datetime64[ns]
#  1   quantity tons  163492 non-null  float64
#  2   customer       163492 non-null  float64
#  3   country        163492 non-null  float64
#  4   status         163492 non-null  int32
#  5   item type      163492 non-null  int32
#  6   application    163492 non-null  float64
#  7   thickness      163492 non-null  float64
#  8   width          163492 non-null  float64
#  9   material_ref   163492 non-null  int32
#  10  product_ref    163492 non-null  int64
#  11  selling_price  163492 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(3), int64(1)
# memory usage: 14.3 MB

# %%
with open('df2_filtered.pkl','wb') as f:
    pickle.dump(df2_filtered, f)

# %%
df4 = df3.drop(['customer','application','material_ref','product_ref'],axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

X= df3.drop(['selling_price','status'],axis=1)
Y_regression = df3['selling_price']
Y_classification =df3['status']


#standard Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

with open('scaler.pkl','wb') as f:
    pickle.dump(scaler, f)

# %%
with open('X.pkl','wb') as f:
    pickle.dump(X, f)

# %%
X_train_reg, X_test_reg, Y_train_reg, Y_test_reg = train_test_split(X_scaled, Y_regression, test_size=0.2, random_state=42)
X_train_clf, X_test_clf, Y_train_clf, Y_test_clf = train_test_split(X_scaled, Y_classification, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import ExtraTreesRegressor, ExtraTreesClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, precision_score, recall_score,f1_score, roc_curve, roc_auc_score

Extree_reg_model = ExtraTreesRegressor()
Extree_reg_model
# Out:
# ExtraTreesRegressor()

# %%
Extree_reg_model.fit(X_train_reg,Y_train_reg)
# Out:
# ExtraTreesRegressor()

# %%
with open('Extree_reg_model.pkl','wb') as f:
    pickle.dump(Extree_reg_model, f)

# %%
Y_pred_reg = Extree_reg_model.predict(X_test_reg)

# %%
# R-squared value
print('r-squared :',r2_score(Y_test_reg, Y_pred_reg))
print('mean_squared :',mean_squared_error(Y_test_reg, Y_pred_reg))
print('mean_avsolute :',mean_absolute_error(Y_test_reg, Y_pred_reg))
# Out:
# r-squared : 0.3672479598320343
# mean_squared : 0.12735229306180318
# mean_avsolute : 0.14654050710312905

# %%
# Train classification model
Extree_clf_model = ExtraTreesClassifier()
Extree_clf_model.fit(X_train_clf, Y_train_clf)
# Out:
# ExtraTreesClassifier()

# %%
with open('Extree_clf_model.pkl','wb') as f:
    pickle.dump(Extree_clf_model, f)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_reg, Y_train_reg)
rf_pred_reg = rf_reg.predict(X_test_reg)

# %%
print('r-squared :',r2_score(Y_test_reg, rf_pred_reg))
print('MSE :',mean_squared_error(Y_test_reg, rf_pred_reg))
print('MAE :',mean_absolute_error(Y_test_reg, rf_pred_reg))
# Out:
# r-squared : 0.4349032494806858
# MSE : 0.11373549575802984
# MAE : 0.14170164999386733

# %%
gb_reg = GradientBoostingRegressor()
gb_reg.fit(X_train_reg, Y_train_reg)
# Out:
# GradientBoostingRegressor()

# %%
gb_pred_reg = gb_reg.predict(X_test_reg)

# %%
print(r2_score(Y_test_reg, gb_pred_reg))
print(mean_squared_error(Y_test_reg, gb_pred_reg))
print(mean_absolute_error(Y_test_reg, gb_pred_reg))
# Out:
# 0.18043433330532554
# 0.16495176679412374
# 0.194354358233437

# %%
Y_pred_clf = Extree_clf_model.predict(X_test_clf)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
accuracy_score(Y_test_clf, Y_pred_clf)
# Out:
# 0.7928619487430424

# %%
classification_report(Y_test_clf, Y_pred_clf)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.58      0.52      0.55       329\n           1       0.73      0.72      0.72      6101\n           2       0.60      0.58      0.59      3687\n           3       0.00      0.00      0.00         3\n           4       0.12      0.11      0.12         9\n           5       0.34      0.28      0.31       735\n           6       0.55      0.52      0.53       733\n           7       0.87      0.88      0.87     21101\n\n    accuracy                           0.79     32698\n   macro avg       0.47      0.45      0.46     32698\nweighted avg       0.79      0.79      0.79     32698\n'

# %%
confusion_matrix(Y_test_clf, Y_pred_clf)
# Out:
# array([[  172,    11,    16,     0,     0,     0,    25,   105],
#        [   14,  4365,   425,     0,     3,    70,    39,  1185],
#        [   11,   451,  2129,     0,     1,    46,    51,   998],
#        [    0,     1,     0,     0,     2,     0,     0,     0],
#        [    0,     2,     0,     1,     1,     0,     0,     5],
#        [    3,    79,    38,     0,     0,   208,     5,   402],
#        [   12,    49,    67,     0,     0,     6,   382,   217],
#        [   84,  1003,   865,     0,     1,   282,   198, 18668]],
#       dtype=int64)
